# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

# Add the parent directory (Auditbot_backend) to the system path
sys.path.append(
    os.path.abspath(
        os.path.join(
            os.path.dirname(f"{os.getcwd()}/RAG_db_NDR.ipynb"),
            '..'
        )
    )
)

# import custom modules
from utils.preprocessing import *
from utils.json_parser import *
from utils.content_page_parser import *
from utils.retriever import *
from utils.custom_print import *
from utils.prompt_engineering import *
from utils.db_utils import *
from utils.langsmith_trace import *
from utils.initialisations import *

# %%
# RAG input parameters =======================================================

# National Day Rally
question = "How are the elderly benifitting ?"

# HYPERPARAMETERS ============================================================

# preprocessing --------------------------------------------------------------

# Chunk into sentences ('s') or paragraphs ('p') or fixed-size strings ('f')
chunking='s' 

# Group smaller chunks into a bigger chunk
grouping=1

# control minimum chunk size
min_chunk_size=100

# vector store ---------------------------------------------------------------

# add to data base in batches
batch_size = 1000

# Ranking --------------------------------------------------------------------

# top k matches for ranking. 
# Both sparse and dense search find top_k matches so hybrid search will return 
# at least top_k matches and most 2 * top_k matches
top_k = 30

# weights for each retrieval for reciprocal rank fusion
weights = [0.5, 0.5]

# reciprocal ranking fusion constant
k = 60

# Reranking ------------------------------------------------------------------

# top n matches for reranking
top_n = 20

# Cross encoder model

# claimed to be deprecated because it is bad but seems to still work fine
# model_name = "cross-encoder/stsb-roberta-base"

# best performing on Microsoft tests
model_name = "cross-encoder/ms-marco-MiniLM-L-12-v2"


# IMPROVEMENTS ===============================================================
HyDE = False
if HyDE:
    comments = "This is using HyDE"
else:
    comments = "None"

# pack parameters for tracing ================================================
params = (question, chunking, grouping, min_chunk_size, batch_size, top_k, 
          weights, k, top_n, model_name, HyDE, comments)

# %%
# RUN ONCE
# generate all required data structures

# generate chunks
generate_chunks(DOCUMENT_DIR_NDR,
                chunks_path,
                chunk_pageNum_pairs_path,
                s_p_pairs_path, 
                chunking, 
                grouping, 
                min_chunk_size,
                DOC_IDENTIFIER_NDR)


# generate inverted tree
has_content_page = False
generate_inverted_tree(chunk_pageNum_pairs_path, 
                       has_content_page, 
                       save_inverted_tree_path,
                       tree_path)
# Out:
# 0.15262699127197266 seconds
# number of chunks: 177

# %%
# RUN ONCE
# retrieve all required data structures

# load tree
inverted_tree = json_file_to_dict(save_inverted_tree_path)

# load chunks from tree's keys
chunks = list(inverted_tree.keys())
print("Number of unique chunks:", len(chunks))

# prepare metadata for chromadb
pre_metadata = list(inverted_tree.values())
metadata = chroma_preprocess_metadata(pre_metadata)

# load sentence paragraph pairs
if (chunking == 's' or chunking == 'f') and grouping == 1:
    print("s_p_pairs will be filled")
    s_p_pairs = json_file_to_dict(s_p_pairs_path)
else:
    s_p_pairs = {}
# Out:
# Number of unique chunks: 177
# s_p_pairs will be filled

# %%
# RUN ONCE
# set up vector database for dense embedding search

# chromadb supported model
openai_ef = embedding_functions.OpenAIEmbeddingFunction(
                api_key=OPENAI_API_KEY,
                model_name="text-embedding-3-small"
            )

# create db
client_dense = chromadb.PersistentClient(path="../data/db", 
                                   settings = Settings(allow_reset=True))

# chromadb's embedding function needs streaming
collection = chroma_get_or_create_collection(client_dense, 
                                             name = "rally", 
                                             embedding_function = openai_ef, 
                                             reset = True)

# fill db
chroma_fill_db(collection, chunks, metadata, batch_size)
print("number of embeddings in database:",collection.count())
# Out:
# number of embeddings in database: 177

# %%
# RUN ONCE
# set up elasticseach for sparse embedding search

# create docker container for elasticsearch on terminal/shell
'''
docker run -p 127.0.0.1:9200:9200 -d --name elasticsearch --network elastic-net \
  -e ELASTIC_PASSWORD=$ELASTIC_PASSWORD \
  -e "discovery.type=single-node" \
  -e "xpack.security.http.ssl.enabled=false" \
  -e "xpack.license.self_generated.type=trial" \
  docker.elastic.co/elasticsearch/elasticsearch:8.14.3
'''

# connect to the Elasticsearch cluster from python elasticsearch client
client_sparce = Elasticsearch(
    LOCAL_HOST_URL,
    basic_auth=HTTP_AUTH
)
# checks if client is connected to docker container
print(client_sparce.info(http_auth=HTTP_AUTH))

# index chunks using elasticsearch (saved in docker)
index_elastic_db(client_sparce, index_name, HTTP_AUTH, chunks, reset = True)
# Out:
# {'name': '50cd72118574', 'cluster_name': 'docker-cluster', 'cluster_uuid': 'l-puMSQDTvqL7nQDfYreOg', 'version': {'number': '8.14.3', 'build_flavor': 'default', 'build_type': 'docker', 'build_hash': 'd55f984299e0e88dee72ebd8255f7ff130859ad0', 'build_date': '2024-07-07T22:04:49.882652950Z', 'build_snapshot': False, 'lucene_version': '9.10.0', 'minimum_wire_compatibility_version': '7.17.0', 'minimum_index_compatibility_version': '7.0.0'}, 'tagline': 'You Know, for Search'}
# reset index: chromadb_documents

# %%
if HyDE:
    query = gpt4o(hyde(question), llm)

else:
    query = question

# %%
# Can be run multiple times when change in query
# 1st ranking

# dense embeding search 
embedding_results = chromadb_embedding_search(collection, query, top_k)

# perform bm_25 using elasticsearch
bm25_results = bm25_elasticsearch(client_sparce, index_name, HTTP_AUTH, query, top_k)


# RRF
good_chunks  = reciprocal_rank_fusion(bm25_results, 
                                 embedding_results, 
                                 weights, 
                                 k)

print("COMBINED RANKING---------------------------------------------------------\n")
pretty_print_list(good_chunks)
# Out:
# COMBINED RANKING---------------------------------------------------------
#
# idx: 0
#
# This is a new housing
# concept that integrates elderly-friendly housing with care and social services
#
# ----------------------------------------------------------
#
# idx: 1
#
# Just as we created Workfare instead
# of Welfare, what would be better than unemployment insurance? How can we
# help in a way that minimises the negative outcomes we have seen elsewhere?
# We discussed this with our brothers and sisters from NTUC and the Labour
# Movement who have been championing this initiative for some time
#
# ----------------------------------------------------------
#
# idx: 2
#
# Anyone who wants to upgrade their skills – at any point in their lives, no matter
# how old – will be given the opportunity to do so in Singapore
#
# ----------------------------------------------------------
#
# idx: 3
#
# We are implementing the new nationwide Age Well SG – to enable our seniors
# to stay active and age well within their communities
#
# ----------------------------------------------------------
#
# idx: 4
#
# More young athletes are taking sports seriously
# , and training full time, with
# support from the government
#
# ----------------------------------------------------------
#
# idx: 5
#
# And when these flats are resold later,
# the additional subsidies will have to be returned to HDB – so it is fair for all
#
# ----------------------------------------------------------
#
# idx: 6
#
# But the parent in fact wanted to know about his child’s overall well-being, and
# how his child was doing as a person
#
# ----------------------------------------------------------
#
# idx: 7
#
# Now you only need one permit for a show, regardless of how many drones you
# use!
# And no more stickers!
# You also save money in the process
#
# ----------------------------------------------------------
#
# idx: 8
#
# But the experience has not always been positive – because after getting a
# generous benefit, the person might find it more attractive to stay unemployed
# than to go back to work
#
# ----------------------------------------------------------
#
# idx: 9
#
# How do we compete and earn our living in such an
# environment?
# We have to work even harder to stay competitive, and push the frontiers of
# innovation and productivity
#
# ----------------------------------------------------------
#
# idx: 10
#
# The keys to the first Community Care Apartments – Harmony Village @ Bukit
# Batok – will be handed over to residents later this year
#
# ----------------------------------------------------------
#
# idx: 11
#
# We seek economic growth, because that is how we create more opportunities
# and a better quality of life for all Singaporeans
#
# ----------------------------------------------------------
#
# idx: 12
#
# And they will be able to service their mortgage mostly with their CPF savings,
# with minimal cash outlay
#
# ----------------------------------------------------------
#
# idx: 13
#
# We are all familiar with the Bay South Garden, this is where the two domes and
# the super-trees are located
#
# ----------------------------------------------------------
#
# idx: 14
#
# Today
# , married children and their parents who are buying new flats to live with
# or near one another get priority access to BTO flats
#
# ----------------------------------------------------------
#
# idx: 15
#
# They asked: what are the teachers doing? Why are my kids spending so much
# time “playing”? Please give them more assignments and homework!
# So these are real challenges our educators face on the ground
#
# ----------------------------------------------------------
#
# idx: 16
#
# They hope for a more caring and gracious society – where there is more support
# for Singaporeans to get over setbacks in life, and where we all do our part to
# help one another succeed
#
# ----------------------------------------------------------
#
# idx: 17
#
# Thank you for
# your service!
# I met several school principals recently
# , to better understand what is happening
# in our schools, and how we can help them do their jobs better
#
# ----------------------------------------------------------
#
# idx: 18
#
# More fathers are playing a bigger role in their families – even changing diapers
# and doing housework!
# I had a chat with a colleague from the Ministry of Finance, Arash
#
# ----------------------------------------------------------
#
# idx: 19
#
# How can our little red dot survive and endure amidst these profound global
# changes?
# Mr Lee Kuan Yew once said that Singapore needs a government that is both
# prudent and bold
#
# ----------------------------------------------------------
#
# idx: 20
#
# We will always keep public housing in Singapore
# affordable for you!
# Besides married couples applying for BTO flats for the first time, I know there
# are other groups concerned about housing
#
# ----------------------------------------------------------
#
# idx: 21
#
# But when the drones are used for a specific purpose, like a show, and they stay
# within a pre-approved area, the risks are more manageable
#
# ----------------------------------------------------------
#
# idx: 22
#
# Beyond the school-based programmes, there will be some students who can
# benefit from even further stretch in particular subjects
#
# ----------------------------------------------------------
#
# idx: 23
#
# A Singapore Government Agency Website How to identify
# National Day Rally 2024
#
# PM Lawrence Wong | 18 August 2024
# Prime Minister and Minister for Finance Lawrence Wong delivered his National Day Rally 2024 speech on 18 August 2024 at
# the Institute of Technical Education (ITE) Headquarters
#
# ----------------------------------------------------------
#
# idx: 24
#
# And we will also do more to help these students build social networks that they
# can tap on later in life
#
# ----------------------------------------------------------
#
# idx: 25
#
# In Singapore, we are very fortunate to have teachers who are dedicated to their
# profession, and deeply committed to bringing out the best in every child
#
# ----------------------------------------------------------
#
# idx: 26
#
# Finally
# , there are restrictions: tighter conditions will apply for the Plus flats and
# the tightest conditions for the Prime flats
#
# ----------------------------------------------------------
#
# idx: 27
#
# It is not possible for them to pursue their goals, and still carry a heavier share of
# the caregiving and housework responsibilities
#
# ----------------------------------------------------------
#
# idx: 28
#
# We are still working out the details of the scheme, and I hope to share the good
# news in the Budget next year
#
# ----------------------------------------------------------
#
# idx: 29
#
# I am sure this will improve things, and I hope this will go some way in helping
# businesses, especially our Small and Medium Enterprises
#
# ----------------------------------------------------------
#
# idx: 30
#
# First, we have location: standard flats are available across the island and remain
# the majority of our housing supply
#
# ----------------------------------------------------------
#
# idx: 31
#
# Now you may ask: what about those
# who choose to train part-time?
# They will continue to receive their salaries, of course
#
# ----------------------------------------------------------
#
# idx: 32
#
# We looked at countries where parents enjoy more generous parental leave, some
# stretching out to a year or more
#
# ----------------------------------------------------------
#
# idx: 33
#
# And we are also providing subsidies for Singaporean students in the new
# university
# , to the same extent as students in our Autonomous Universities
#
# ----------------------------------------------------------
#
# idx: 34
#
# Next we have subsidies: the usual subsidies for standard flats, more for the Plus
# flats, and the most subsidies for the Prime flats
#
# ----------------------------------------------------------
#
# idx: 35
#
# and skills of the heart, which are needed
# in many critical areas that demand empathy and human connections
#
# ----------------------------------------------------------
#
# idx: 36
#
# I know in some areas it can still be difficult to find places, especially in new
# housing developments
#
# ----------------------------------------------------------
#
# idx: 37
#
# We have also removed streaming in secondary school – Express, N(A) and N(T),
# these are things of the past
#
# ----------------------------------------------------------
#
# idx: 38
#
# But employers and businesses are concerned about managing manpower gaps
# when their employees are away for an extended period
#
# ----------------------------------------------------------
#
# idx: 39
#
# This will create more opportunities for
# Singaporeans to pursue degrees in much-needed areas like early childhood
# education, and social work
#
# ----------------------------------------------------------
#
# idx: 40
#
# It is not easy for our children, who are all growing up in an environment where
# English is the main language
#
# ----------------------------------------------------------
#
# idx: 41
#
# The Progression Award will provide him with a $5,000 top-up in his Post-
# Secondary Education Account
#
# ----------------------------------------------------------
#
# idx: 42
#
# If you do the sums, that adds up to $72,000 per person!
# So you can space out your training, and get fresh injection of skills whenever
# you need it as you progress in your career
#
# ----------------------------------------------------------
#
# idx: 43
#
# It is hard for us to make any major near-term changes, because we are still
# ramping up the supply of new flats to catch up with the demand
#
# ----------------------------------------------------------
#
# idx: 44
#
# We will equip the schools to identify their own high-ability learners – so this
# will benefit more students
#
# ----------------------------------------------------------
#
# idx: 45
#
# Nowadays going to the right school
# is very important! So what to do!
# In the end, Singaporeans will have their own preferences and considerations
# where school choices are concerned
#
# ----------------------------------------------------------
#
# idx: 46
#
# Whether it is preschool, parental leave or housing, we will do whatever we can
# to strengthen families in Singapore
#
# ----------------------------------------------------------
#
# idx: 47
#
# They seek a more inclusive society
# , with space to explore and experiment, and
# opportunities to pursue their chosen paths, including less conventional ones, off
# the beaten tracks
#
# ----------------------------------------------------------
#
# idx: 48
#
# Well done Team Singapore!
# And to our Paralympians, we also wish you all the very best for the Games!
# I am glad that more young Singaporeans with the talent in sports are taking it
# seriously
# , and excelling at the highest levels
#
# ----------------------------------------------------------
#
# idx: 49
#
# So from next year, we will provide a new training allowance under the
# SkillsFuture Level-Up programme
#
# ----------------------------------------------------------
#
# idx: 50
#
# We will bring together the national training centres for several key sports –
# which are now spread out all over the island, and we will site them here under
# one roof for better synergies
#
# ----------------------------------------------------------
#
# idx: 51
#
# The credits are already in your accounts!
# Please take full advantage and make good use of them!
# Of course effective skills upgrading takes commitment and time
#
# ----------------------------------------------------------
#
# idx: 52
#
# European and other developed countries too are taking the same approach – to
# rebuild their critical industries, and to re-shape global supply chains in their
# favour
#
# ----------------------------------------------------------
#
# idx: 53
#
# where all citizens, even the most disadvantaged amongst us, know that
# they can get a fair shot in life, that they can get ahead if they make the effort
# and work hard
#
# ----------------------------------------------------------

# %%
embedding_list, embedding_rank = zip(*embedding_results)
print("DENSE RETRIEVAL RANKING---------------------------------------------------------\n")
pretty_print_list(embedding_list)
# Out:
# DENSE RETRIEVAL RANKING---------------------------------------------------------
#
# idx: 0
#
# We are implementing the new nationwide Age Well SG – to enable our seniors
# to stay active and age well within their communities
#
# ----------------------------------------------------------
#
# idx: 1
#
# This is a new housing
# concept that integrates elderly-friendly housing with care and social services
#
# ----------------------------------------------------------
#
# idx: 2
#
# But the experience has not always been positive – because after getting a
# generous benefit, the person might find it more attractive to stay unemployed
# than to go back to work
#
# ----------------------------------------------------------
#
# idx: 3
#
# Just as we created Workfare instead
# of Welfare, what would be better than unemployment insurance? How can we
# help in a way that minimises the negative outcomes we have seen elsewhere?
# We discussed this with our brothers and sisters from NTUC and the Labour
# Movement who have been championing this initiative for some time
#
# ----------------------------------------------------------
#
# idx: 4
#
# The keys to the first Community Care Apartments – Harmony Village @ Bukit
# Batok – will be handed over to residents later this year
#
# ----------------------------------------------------------
#
# idx: 5
#
# And they will be able to service their mortgage mostly with their CPF savings,
# with minimal cash outlay
#
# ----------------------------------------------------------
#
# idx: 6
#
# Today
# , married children and their parents who are buying new flats to live with
# or near one another get priority access to BTO flats
#
# ----------------------------------------------------------
#
# idx: 7
#
# They hope for a more caring and gracious society – where there is more support
# for Singaporeans to get over setbacks in life, and where we all do our part to
# help one another succeed
#
# ----------------------------------------------------------
#
# idx: 8
#
# More fathers are playing a bigger role in their families – even changing diapers
# and doing housework!
# I had a chat with a colleague from the Ministry of Finance, Arash
#
# ----------------------------------------------------------
#
# idx: 9
#
# We will always keep public housing in Singapore
# affordable for you!
# Besides married couples applying for BTO flats for the first time, I know there
# are other groups concerned about housing
#
# ----------------------------------------------------------
#
# idx: 10
#
# Beyond the school-based programmes, there will be some students who can
# benefit from even further stretch in particular subjects
#
# ----------------------------------------------------------
#
# idx: 11
#
# More young athletes are taking sports seriously
# , and training full time, with
# support from the government
#
# ----------------------------------------------------------
#
# idx: 12
#
# And we will also do more to help these students build social networks that they
# can tap on later in life
#
# ----------------------------------------------------------
#
# idx: 13
#
# Anyone who wants to upgrade their skills – at any point in their lives, no matter
# how old – will be given the opportunity to do so in Singapore
#
# ----------------------------------------------------------
#
# idx: 14
#
# It is not possible for them to pursue their goals, and still carry a heavier share of
# the caregiving and housework responsibilities
#
# ----------------------------------------------------------
#
# idx: 15
#
# I am sure this will improve things, and I hope this will go some way in helping
# businesses, especially our Small and Medium Enterprises
#
# ----------------------------------------------------------
#
# idx: 16
#
# Now you may ask: what about those
# who choose to train part-time?
# They will continue to receive their salaries, of course
#
# ----------------------------------------------------------
#
# idx: 17
#
# We looked at countries where parents enjoy more generous parental leave, some
# stretching out to a year or more
#
# ----------------------------------------------------------
#
# idx: 18
#
# Next we have subsidies: the usual subsidies for standard flats, more for the Plus
# flats, and the most subsidies for the Prime flats
#
# ----------------------------------------------------------
#
# idx: 19
#
# I know in some areas it can still be difficult to find places, especially in new
# housing developments
#
# ----------------------------------------------------------
#
# idx: 20
#
# And when these flats are resold later,
# the additional subsidies will have to be returned to HDB – so it is fair for all
#
# ----------------------------------------------------------
#
# idx: 21
#
# This will create more opportunities for
# Singaporeans to pursue degrees in much-needed areas like early childhood
# education, and social work
#
# ----------------------------------------------------------
#
# idx: 22
#
# The Progression Award will provide him with a $5,000 top-up in his Post-
# Secondary Education Account
#
# ----------------------------------------------------------
#
# idx: 23
#
# If you do the sums, that adds up to $72,000 per person!
# So you can space out your training, and get fresh injection of skills whenever
# you need it as you progress in your career
#
# ----------------------------------------------------------
#
# idx: 24
#
# We will equip the schools to identify their own high-ability learners – so this
# will benefit more students
#
# ----------------------------------------------------------
#
# idx: 25
#
# Whether it is preschool, parental leave or housing, we will do whatever we can
# to strengthen families in Singapore
#
# ----------------------------------------------------------
#
# idx: 26
#
# They seek a more inclusive society
# , with space to explore and experiment, and
# opportunities to pursue their chosen paths, including less conventional ones, off
# the beaten tracks
#
# ----------------------------------------------------------
#
# idx: 27
#
# So from next year, we will provide a new training allowance under the
# SkillsFuture Level-Up programme
#
# ----------------------------------------------------------
#
# idx: 28
#
# The credits are already in your accounts!
# Please take full advantage and make good use of them!
# Of course effective skills upgrading takes commitment and time
#
# ----------------------------------------------------------
#
# idx: 29
#
# where all citizens, even the most disadvantaged amongst us, know that
# they can get a fair shot in life, that they can get ahead if they make the effort
# and work hard
#
# ----------------------------------------------------------

# %%
bm25_list, bm25_rank = zip(*bm25_results)
print("SPARSE RETRIEVAL RANKING---------------------------------------------------------\n")
pretty_print_list(bm25_list)
# Out:
# SPARSE RETRIEVAL RANKING---------------------------------------------------------
#
# idx: 0
#
# This is a new housing
# concept that integrates elderly-friendly housing with care and social services
#
# ----------------------------------------------------------
#
# idx: 1
#
# But the parent in fact wanted to know about his child’s overall well-being, and
# how his child was doing as a person
#
# ----------------------------------------------------------
#
# idx: 2
#
# Now you only need one permit for a show, regardless of how many drones you
# use!
# And no more stickers!
# You also save money in the process
#
# ----------------------------------------------------------
#
# idx: 3
#
# Anyone who wants to upgrade their skills – at any point in their lives, no matter
# how old – will be given the opportunity to do so in Singapore
#
# ----------------------------------------------------------
#
# idx: 4
#
# How do we compete and earn our living in such an
# environment?
# We have to work even harder to stay competitive, and push the frontiers of
# innovation and productivity
#
# ----------------------------------------------------------
#
# idx: 5
#
# We seek economic growth, because that is how we create more opportunities
# and a better quality of life for all Singaporeans
#
# ----------------------------------------------------------
#
# idx: 6
#
# We are all familiar with the Bay South Garden, this is where the two domes and
# the super-trees are located
#
# ----------------------------------------------------------
#
# idx: 7
#
# They asked: what are the teachers doing? Why are my kids spending so much
# time “playing”? Please give them more assignments and homework!
# So these are real challenges our educators face on the ground
#
# ----------------------------------------------------------
#
# idx: 8
#
# Thank you for
# your service!
# I met several school principals recently
# , to better understand what is happening
# in our schools, and how we can help them do their jobs better
#
# ----------------------------------------------------------
#
# idx: 9
#
# How can our little red dot survive and endure amidst these profound global
# changes?
# Mr Lee Kuan Yew once said that Singapore needs a government that is both
# prudent and bold
#
# ----------------------------------------------------------
#
# idx: 10
#
# But when the drones are used for a specific purpose, like a show, and they stay
# within a pre-approved area, the risks are more manageable
#
# ----------------------------------------------------------
#
# idx: 11
#
# A Singapore Government Agency Website How to identify
# National Day Rally 2024
#
# PM Lawrence Wong | 18 August 2024
# Prime Minister and Minister for Finance Lawrence Wong delivered his National Day Rally 2024 speech on 18 August 2024 at
# the Institute of Technical Education (ITE) Headquarters
#
# ----------------------------------------------------------
#
# idx: 12
#
# Just as we created Workfare instead
# of Welfare, what would be better than unemployment insurance? How can we
# help in a way that minimises the negative outcomes we have seen elsewhere?
# We discussed this with our brothers and sisters from NTUC and the Labour
# Movement who have been championing this initiative for some time
#
# ----------------------------------------------------------
#
# idx: 13
#
# In Singapore, we are very fortunate to have teachers who are dedicated to their
# profession, and deeply committed to bringing out the best in every child
#
# ----------------------------------------------------------
#
# idx: 14
#
# Finally
# , there are restrictions: tighter conditions will apply for the Plus flats and
# the tightest conditions for the Prime flats
#
# ----------------------------------------------------------
#
# idx: 15
#
# We are still working out the details of the scheme, and I hope to share the good
# news in the Budget next year
#
# ----------------------------------------------------------
#
# idx: 16
#
# First, we have location: standard flats are available across the island and remain
# the majority of our housing supply
#
# ----------------------------------------------------------
#
# idx: 17
#
# More young athletes are taking sports seriously
# , and training full time, with
# support from the government
#
# ----------------------------------------------------------
#
# idx: 18
#
# And we are also providing subsidies for Singaporean students in the new
# university
# , to the same extent as students in our Autonomous Universities
#
# ----------------------------------------------------------
#
# idx: 19
#
# and skills of the heart, which are needed
# in many critical areas that demand empathy and human connections
#
# ----------------------------------------------------------
#
# idx: 20
#
# We have also removed streaming in secondary school – Express, N(A) and N(T),
# these are things of the past
#
# ----------------------------------------------------------
#
# idx: 21
#
# But employers and businesses are concerned about managing manpower gaps
# when their employees are away for an extended period
#
# ----------------------------------------------------------
#
# idx: 22
#
# It is not easy for our children, who are all growing up in an environment where
# English is the main language
#
# ----------------------------------------------------------
#
# idx: 23
#
# We are implementing the new nationwide Age Well SG – to enable our seniors
# to stay active and age well within their communities
#
# ----------------------------------------------------------
#
# idx: 24
#
# It is hard for us to make any major near-term changes, because we are still
# ramping up the supply of new flats to catch up with the demand
#
# ----------------------------------------------------------
#
# idx: 25
#
# Nowadays going to the right school
# is very important! So what to do!
# In the end, Singaporeans will have their own preferences and considerations
# where school choices are concerned
#
# ----------------------------------------------------------
#
# idx: 26
#
# And when these flats are resold later,
# the additional subsidies will have to be returned to HDB – so it is fair for all
#
# ----------------------------------------------------------
#
# idx: 27
#
# Well done Team Singapore!
# And to our Paralympians, we also wish you all the very best for the Games!
# I am glad that more young Singaporeans with the talent in sports are taking it
# seriously
# , and excelling at the highest levels
#
# ----------------------------------------------------------
#
# idx: 28
#
# We will bring together the national training centres for several key sports –
# which are now spread out all over the island, and we will site them here under
# one roof for better synergies
#
# ----------------------------------------------------------
#
# idx: 29
#
# European and other developed countries too are taking the same approach – to
# rebuild their critical industries, and to re-shape global supply chains in their
# favour
#
# ----------------------------------------------------------

# %%
# Can be run multiple times when change in query
# Reranking
best_chunks, scores = reranking(model_name, good_chunks, query, top_n)

print("RERANKING-----------------------------------------------------------\n")
pretty_print_rank(best_chunks, scores)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# RERANKING-----------------------------------------------------------
#
# RANK: 1
#
# This is a new housing
# concept that integrates elderly-friendly housing with care and social services
#
# SCORE: -9.43601
#
# ----------------------------------------------------------
#
# RANK: 2
#
# We are implementing the new nationwide Age Well SG – to enable our seniors
# to stay active and age well within their communities
#
# SCORE: -10.325906
#
# ----------------------------------------------------------
#
# RANK: 3
#
# Anyone who wants to upgrade their skills – at any point in their lives, no matter
# how old – will be given the opportunity to do so in Singapore
#
# SCORE: -10.97282
#
# ----------------------------------------------------------
#
# RANK: 4
#
# More fathers are playing a bigger role in their families – even changing diapers
# and doing housework!
# I had a chat with a colleague from the Ministry of Finance, Arash
#
# SCORE: -11.105978
#
# ----------------------------------------------------------
#
# RANK: 5
#
# But employers and businesses are concerned about managing manpower gaps
# when their employees are away for an extended period
#
# SCORE: -11.172245
#
# ----------------------------------------------------------
#
# RANK: 6
#
# It is not possible for them to pursue their goals, and still carry a heavier share of
# the caregiving and housework responsibilities
#
# SCORE: -11.1872425
#
# ----------------------------------------------------------
#
# RANK: 7
#
# We are all familiar with the Bay South Garden, this is where the two domes and
# the super-trees are located
#
# SCORE: -11.248441
#
# ----------------------------------------------------------
#
# RANK: 8
#
# They asked: what are the teachers doing? Why are my kids spending so much
# time “playing”? Please give them more assignments and homework!
# So these are real challenges our educators face on the ground
#
# SCORE: -11.248546
#
# ----------------------------------------------------------
#
# RANK: 9
#
# I know in some areas it can still be difficult to find places, especially in new
# housing developments
#
# SCORE: -11.252287
#
# ----------------------------------------------------------
#
# RANK: 10
#
# We are still working out the details of the scheme, and I hope to share the good
# news in the Budget next year
#
# SCORE: -11.261278
#
# ----------------------------------------------------------
#
# RANK: 11
#
# Thank you for
# your service!
# I met several school principals recently
# , to better understand what is happening
# in our schools, and how we can help them do their jobs better
#
# SCORE: -11.26206
#
# ----------------------------------------------------------
#
# RANK: 12
#
# We will equip the schools to identify their own high-ability learners – so this
# will benefit more students
#
# SCORE: -11.26932
#
# ----------------------------------------------------------
#
# RANK: 13
#
# Nowadays going to the right school
# is very important! So what to do!
# In the end, Singaporeans will have their own preferences and considerations
# where school choices are concerned
#
# SCORE: -11.270883
#
# ----------------------------------------------------------
#
# RANK: 14
#
# They hope for a more caring and gracious society – where there is more support
# for Singaporeans to get over setbacks in life, and where we all do our part to
# help one another succeed
#
# SCORE: -11.270935
#
# ----------------------------------------------------------
#
# RANK: 15
#
# Now you may ask: what about those
# who choose to train part-time?
# They will continue to receive their salaries, of course
#
# SCORE: -11.273404
#
# ----------------------------------------------------------
#
# RANK: 16
#
# Beyond the school-based programmes, there will be some students who can
# benefit from even further stretch in particular subjects
#
# SCORE: -11.273618
#
# ----------------------------------------------------------
#
# RANK: 17
#
# And we are also providing subsidies for Singaporean students in the new
# university
# , to the same extent as students in our Autonomous Universities
#
# SCORE: -11.274691
#
# ----------------------------------------------------------
#
# RANK: 18
#
# Next we have subsidies: the usual subsidies for standard flats, more for the Plus
# flats, and the most subsidies for the Prime flats
#
# SCORE: -11.2758465
#
# ----------------------------------------------------------
#
# RANK: 19
#
# The credits are already in your accounts!
# Please take full advantage and make good use of them!
# Of course effective skills upgrading takes commitment and time
#
# SCORE: -11.276008
#
# ----------------------------------------------------------
#
# RANK: 20
#
# So from next year, we will provide a new training allowance under the
# SkillsFuture Level-Up programme
#
# SCORE: -11.282176
#
# ----------------------------------------------------------

# %%
# Can be run multiple times when change in query
# in utils.preprocessing, change 
prompt = generate_prompt(question, 
                         inverted_tree, 
                         best_chunks, 
                         chunking, 
                         s_p_pairs,
                         document = "NDR")

print(prompt)
# Out:
# Role:
# You are a journalist in charge of the Singapore National Day Rally (NDR).
# You have to use context from the NDR transcription to answer the query.
#
# Instruction:
# Your response should cite the source's year. Don't cite the context number.
# Categorise your answers and provide headings.
# If you are unable to provide an answer, state "Unable to find, submit prompt again."
#
# Background:
# The contexts are taken from a speech given by Singapore Prime Minister during the National Day Rally (NDR).
# NDR is an annual event where the Prime Minister addresses the nation on key issues and policies, and update Singaporeans on the country’s progress.
#
# CONTEXT
# Context 0:
# Year: 2024
# Page number: Introduction
# Content: We have introduced the Community Care Apartments. This is a new housing
# concept that integrates elderly-friendly housing with care and social services
#
# Context 1:
# Year: 2024
# Page number: Introduction
# Content: We are implementing the new nationwide Age Well SG – to enable our seniors
# to stay active and age well within their communities
#
# Context 2:
# Year: 2024
# Page number: Introduction
# Content: Anyone who wants to upgrade their skills – at any point in their lives, no matter
# how old – will be given the opportunity to do so in Singapore
#
# Context 3:
# Year: 2024
# Page number: Introduction
# Content: More fathers are playing a bigger role in their families – even changing diapers
# and doing housework!
# I had a chat with a colleague from the Ministry of Finance, Arash. He became a
# father when he was busy helping me with Budget preparations two years ago
#
# Context 4:
# Year: 2024
# Page number: Introduction
# Content: But employers and businesses are concerned about managing manpower gaps
# when their employees are away for an extended period
#
# Context 5:
# Year: 2024
# Page number: Introduction
# Content: It is not possible for them to pursue their goals, and still carry a heavier share of
# the caregiving and housework responsibilities
#
# Context 6:
# Year: 2024
# Page number: Introduction
# Content: We are all familiar with the Bay South Garden, this is where the two domes and
# the super-trees are located
#
# Context 7:
# Year: 2024
# Page number: Introduction
# Content: They asked: what are the teachers doing? Why are my kids spending so much
# time “playing”? Please give them more assignments and homework!
# So these are real challenges our educators face on the ground
#
# Context 8:
# Year: 2024
# Page number: Introduction
# Content: I know in some areas it can still be difficult to find places, especially in new
# housing developments
#
# Context 9:
# Year: 2024
# Page number: Introduction
# Content: We are still working out the details of the scheme, and I hope to share the good
# news in the Budget next year
#
# Context 10:
# Year: 2024
# Page number: Introduction
# Content: Several of them are here with us this evening. We salute you. Thank you for
# your service!
# I met several school principals recently
# , to better understand what is happening
# in our schools, and how we can help them do their jobs better. I was very
# encouraged by their enthusiasm and passion
#
# Context 11:
# Year: 2024
# Page number: Introduction
# Content: We will equip the schools to identify their own high-ability learners – so this
# will benefit more students
#
# Context 12:
# Year: 2024
# Page number: Introduction
# Content: But they reply: No, you are the exception. Nowadays going to the right school
# is very important! So what to do!
# In the end, Singaporeans will have their own preferences and considerations
# where school choices are concerned. It will not be possible to convince everyone
#
# Context 13:
# Year: 2024
# Page number: Introduction
# Content: They hope for a more caring and gracious society – where there is more support
# for Singaporeans to get over setbacks in life, and where we all do our part to
# help one another succeed
#
# Context 14:
# Year: 2024
# Page number: Introduction
# Content: This is for those taking full-time courses. Now you may ask: what about those
# who choose to train part-time?
# They will continue to receive their salaries, of course
#
# Context 15:
# Year: 2024
# Page number: Introduction
# Content: Beyond the school-based programmes, there will be some students who can
# benefit from even further stretch in particular subjects. They can come together
# for after-school enrichment modules in a nearby school, to learn and interact
# with one another
#
# Context 16:
# Year: 2024
# Page number: Introduction
# Content: And we are also providing subsidies for Singaporean students in the new
# university
# , to the same extent as students in our Autonomous Universities
#
# Context 17:
# Year: 2024
# Page number: Introduction
# Content: Next we have subsidies: the usual subsidies for standard flats, more for the Plus
# flats, and the most subsidies for the Prime flats. This will keep the Plus and
# Prime flats within reach of the majority of Singaporeans
#
# Context 18:
# Year: 2024
# Page number: Introduction
# Content: The credits are already in your accounts!
# Please take full advantage and make good use of them!
# Of course effective skills upgrading takes commitment and time
#
# Context 19:
# Year: 2024
# Page number: Introduction
# Content: So from next year, we will provide a new training allowance under the
# SkillsFuture Level-Up programme
#
# Query: How are the elderly benifitting ?

# %%
# as comparison
# Can be run multiple times when change in query
bad_prompt = generate_bad_prompt(
    question, 
    best_chunks, 
    chunking, 
    s_p_pairs
)

print(bad_prompt)
# Out:
# We have introduced the Community Care Apartments. This is a new housing
# concept that integrates elderly-friendly housing with care and social services
#
# We are implementing the new nationwide Age Well SG – to enable our seniors
# to stay active and age well within their communities
#
# Anyone who wants to upgrade their skills – at any point in their lives, no matter
# how old – will be given the opportunity to do so in Singapore
#
# More fathers are playing a bigger role in their families – even changing diapers
# and doing housework!
# I had a chat with a colleague from the Ministry of Finance, Arash. He became a
# father when he was busy helping me with Budget preparations two years ago
#
# But employers and businesses are concerned about managing manpower gaps
# when their employees are away for an extended period
#
# It is not possible for them to pursue their goals, and still carry a heavier share of
# the caregiving and housework responsibilities
#
# We are all familiar with the Bay South Garden, this is where the two domes and
# the super-trees are located
#
# They asked: what are the teachers doing? Why are my kids spending so much
# time “playing”? Please give them more assignments and homework!
# So these are real challenges our educators face on the ground
#
# I know in some areas it can still be difficult to find places, especially in new
# housing developments
#
# We are still working out the details of the scheme, and I hope to share the good
# news in the Budget next year
#
# Several of them are here with us this evening. We salute you. Thank you for
# your service!
# I met several school principals recently
# , to better understand what is happening
# in our schools, and how we can help them do their jobs better. I was very
# encouraged by their enthusiasm and passion
#
# We will equip the schools to identify their own high-ability learners – so this
# will benefit more students
#
# But they reply: No, you are the exception. Nowadays going to the right school
# is very important! So what to do!
# In the end, Singaporeans will have their own preferences and considerations
# where school choices are concerned. It will not be possible to convince everyone
#
# They hope for a more caring and gracious society – where there is more support
# for Singaporeans to get over setbacks in life, and where we all do our part to
# help one another succeed
#
# This is for those taking full-time courses. Now you may ask: what about those
# who choose to train part-time?
# They will continue to receive their salaries, of course
#
# Beyond the school-based programmes, there will be some students who can
# benefit from even further stretch in particular subjects. They can come together
# for after-school enrichment modules in a nearby school, to learn and interact
# with one another
#
# And we are also providing subsidies for Singaporean students in the new
# university
# , to the same extent as students in our Autonomous Universities
#
# Next we have subsidies: the usual subsidies for standard flats, more for the Plus
# flats, and the most subsidies for the Prime flats. This will keep the Plus and
# Prime flats within reach of the majority of Singaporeans
#
# The credits are already in your accounts!
# Please take full advantage and make good use of them!
# Of course effective skills upgrading takes commitment and time
#
# So from next year, we will provide a new training allowance under the
# SkillsFuture Level-Up programme
#
# Query: How are the elderly benifitting ?

# %%
# response = rag_pipeline(params, prompt, llm)
# I get a deadlock error when placed in another file. Is this ok?
# yes, it's ok. Doesn't affect the LLM outputs. So just disable parallelism since not needed 
'''
huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
To disable this warning, you can either:
	- Avoid using `tokenizers` before the fork if possible
	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
'''

# %%
os.environ["TOKENIZERS_PARALLELISM"] = "false"

response = rag_pipeline(params, prompt, llm)
# Out:
# ### Elderly Benefits
#
# **Community Care Apartments (2024)**
# - The introduction of Community Care Apartments integrates elderly-friendly housing with care and social services. This new housing concept aims to provide a supportive living environment for the elderly, enhancing their quality of life by combining accommodation with necessary care and social support (Context 0, 2024).
#
# **Nationwide Age Well SG Programme (2024)**
# - The implementation of the Age Well SG programme is designed to enable seniors to stay active and age well within their communities. This initiative focuses on promoting the well-being of the elderly by encouraging them to remain engaged and healthy (Context 1, 2024).
#
# ### General Support for Skills Upgrade
#
# **Opportunities for Lifelong Learning (2024)**
# - Additionally, Singapore is enabling individuals of any age to upgrade their skills at any point in their lives. This policy ensures that elderly members of society, who wish to learn new skills or enhance existing ones, have the opportunity to do so, thereby staying productive and engaged (Context 2, 2024).
#
# ### Social and Financial Support
#
# **Subsidies for Housing (2024)**
# - There are also provisions for subsidies for housing, including standard, Plus, and Prime flats, which can help elderly citizens afford quality housing. These subsidies aim to keep such accommodations within reach for the majority of Singaporeans, ensuring that the elderly have access to suitable living conditions (Context 17, 2024).

# %%
os.environ["TOKENIZERS_PARALLELISM"] = "false"

bad_response = rag_pipeline(params, bad_prompt, llm)
# Out:
# The elderly in Singapore are benefiting through several initiatives and programmes:
#
# 1. **Community Care Apartments**: This new housing concept integrates elderly-friendly housing with care and social services. It is designed to meet the needs of senior citizens, ensuring they have a conducive living environment that supports their health and well-being.
#
# 2. **Age Well SG**: Under this nationwide programme, seniors are encouraged to stay active and age well within their communities. This enables them to lead fulfilling lives with activities and opportunities to engage socially, which is crucial for their mental and physical health.
#
# 3. **Skills Upgrading Opportunities**: Seniors who wish to upgrade their skills have the opportunity to do so at any point in their lives. This lifelong learning initiative ensures that the elderly can continue to learn and grow, staying relevant and engaged in various aspects of life.
#
# 4. **Subsidies for Housing**: Subsidies for Plus and Prime flats ensure housing remains affordable for the elderly, especially in new housing developments.
#
# 5. **Training Allowances**: Starting from next year, the SkillsFuture Level-Up programme will provide a new training allowance to aid those seeking to upgrade their skills, including seniors.
#
# These initiatives collectively aim to provide a robust support system that addresses the housing, social, health, and continuous learning needs of the elderly in Singapore, thus promoting a more inclusive and caring society.
