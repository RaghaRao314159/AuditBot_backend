# %%
# https://github.com/microsoft/LLMLingua

# THIS JUPYTER NOTEBOOK WAS RUN ON GOOGLE COLAB

# %%
# %pip install llmlingua optimum auto-gptq
# Out:
# hyde.ipynb                recursive_retrieval.ipynb
# prompt_compression.ipynb  tables.ipynb

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# useful python modules
import sys
import os
import tiktoken

from llmlingua import PromptCompressor


# Add the parent directory (Auditbot_backend) to the system path
sys.path.append(
    os.path.abspath(
        os.path.join(
            os.path.dirname(f"{os.getcwd()}/prompt_compression.ipynb"),
            '..'
        )
    )
)

# with hyde
from utils.langsmith_trace import gpt4o_untraced, llm
# from utils.initialisations import *

# %%
def count_tokens(text, model):
    # Initialize the tokenizer for the specified model
    encoding = tiktoken.encoding_for_model(model)
    
    # Encode the text to get the tokens
    tokens = encoding.encode(text)
    
    # Return the number of tokens
    return len(tokens)

# %%
prompt = "Role:\nYou are a specialist who uses the context provided to answer the query.\n\nInstruction:\nYour response should cite sources' year and page number.\nIf possible, make ministries or government agencies the headings.\n\nBackground:\nThe context is taken from audit reports from the Auditor-General's Office (AGO) of Singapore. \nAGO is an independent organ of state and the national auditor. They play an important role in enhancing public accountability in the management and use of public funds and resources through their audits.\n\nThey audit\n    government ministries and departments\n    organs of state\n    statutory boards\n    government funds\n    other public authorities and bodies administering public funds (upon their request for audit), e.g. government-owned companies.\n\nThey report their audit observations to the President, Parliament and the public through the Annual Report of the Auditor-General management of the organisations audited through management letters.\nTheir observations include system weaknesses, non-compliance with control procedures or legislation, and instances of excess, extravagance, or gross inefficiency leading to waste in the use of public funds and resources.\n\nCONTEXT\nContext 0:\nYear: 2019_20\nLocation in document: PART III : THEMATIC AUDIT, SUMMARY\nPage number: 53\nContent: Stage 2: Grant Evaluation and Approval\n– whether there were processes and controls in place to ensure that \ngrant applications were properly evaluated and approved; and\n– whether agreements with grant recipients were properly entered into\n\nContext 1:\nYear: 2022_23\nLocation in document: PART III : THEMATIC AUDIT – COVID-19 RELATED GRANTS, SUMMARY\nPage number: 48\nContent: Stage 2: Grant Evaluation and Approval\n–\t\nWhether there were processes and controls in place to ensure \nthat grant cases were properly evaluated and approved; and\n–\t\nWhether proper terms and conditions were stipulated for \ncompliance\n\nContext 2:\nYear: 2017_18\nLocation in document: PART III: THEMATIC AUDIT, SUMMARY\nPage number: 45\nContent: The audit examined whether there was a proper framework for grant \nmanagement and whether due process was followed for the above stages by the two \nagencies.  For grants that were jointly managed by A*STAR/NRF and one or more \nother agencies, the audit focus was on A*STAR/NRF’s role and responsibilities in \nthe grant management\n\nContext 3:\nYear: 2017_18\nLocation in document: PART III: THEMATIC AUDIT, SUMMARY\nPage number: 45\nContent: Application, evaluation and award of grants \n– whether the processes to invite, receive, evaluate and approve \nproposals and contract with grant recipients2 were properly administered\nb\n\nContext 4:\nYear: 2019_20\nLocation in document: PART III : THEMATIC AUDIT, SUMMARY\nPage number: 54\nContent: Stage 4: Grant Monitoring and Review\n– whether there were processes and controls in place to ensure that \ngrants were managed in accordance with relevant terms and conditions, \nand that the deliverables were achieved\n\nContext 5:\nYear: 2019_20\nLocation in document: PART III : THEMATIC AUDIT, SUMMARY\nPage number: 54\nContent: The audit examined whether there was a proper framework for grant \nmanagement and whether due process was followed for the above stages.  The audit \ndid not seek to certify whether the grant recipients had, in all material aspects, used or \nmanaged the grants in accordance with the grant terms and conditions.  For grants \nwhich were managed by WSG and ESG jointly with their programme partners (PPs) \nsuch as Trade Associations and Chambers (TACs), the audit focus was on WSG’s \nand ESG’s roles and responsibilities in the grant management\n\nContext 6:\nYear: 2022_23\nLocation in document: PART III : THEMATIC AUDIT – COVID-19 RELATED GRANTS, SUMMARY\nPage number: 49\nContent: Stage 4: Grant Monitoring and Review\n–\t\nWhether there were processes and controls in place to ensure \nthat grants were managed in accordance with relevant terms \nand conditions, and that the deliverables were achieved\n\nContext 7:\nYear: 2018_19\nLocation in document: PART III : THEMATIC AUDIT, SUMMARY\nPage number: 54\nContent: Stage 1: Grant Design and Setup\n– whether processes were in place to ensure that grant programmes \nwere authorised and reviewed for relevance\nb\n\nContext 8:\nYear: 2018_19\nLocation in document: OVERVIEW, SUMMARY\nPage number: 8\nContent: 8\nOverview\nGrant Design and Setup\nAGO found that MOH and MSF had put in place processes for approving new grant \nprogrammes and renewal of grant programmes.  By and large, grant programmes \nmanaged by both ministries had defined objectives and clear service deliverables \nwhich were approved by the correct approving authority\n\nContext 9:\nYear: 2019_20\nLocation in document: PART III : THEMATIC AUDIT, SUMMARY\nPage number: 53\nContent: Stage 1: Grant Design and Setup\n– whether there were processes and controls in place to ensure that \ngrant programmes were authorised and administered in accordance \nwith the objective(s) of the grant\n\nContext 10:\nYear: 2022_23\nLocation in document: PART III : THEMATIC AUDIT – COVID-19 RELATED GRANTS, SUMMARY\nPage number: 48\nContent: Stage 1: Grant Design and Setup\n–\t\nWhether there were processes and controls in place to ensure \nthat COVID-19 grant schemes were authorised and administered \nin accordance with the objectives of the schemes\n\nContext 11:\nYear: 2019_20\nLocation in document: PART III : THEMATIC AUDIT, SUMMARY\nPage number: 57\nContent: Nevertheless, AGO noted some areas for improvement.  For WSG, there \nis a need for better oversight of PPs which administer grants on its behalf.  This \nis especially important as the PPs were of varying sizes and had different systems \nof controls.  AGO found inconsistent practices across PPs in their stipulation of \nrequirements to grant recipients and their checks performed on grant applications\n\nContext 12:\nYear: 2011_12\nLocation in document: OVERVIEW, SUMMARY\nPage number: 5\nContent: Audit Observations\nMain Findings\nA substantial portion of the audit findings pertains to procurement and contract \nmanagement, and financial administration.  The lapses and irregularities point to the need \nfor the public sector agencies concerned to make improvements to the following areas\n\nContext 13:\nYear: 2022_23\nLocation in document: OVERVIEW, SUMMARY\nPage number: 8\nContent: Stage 1 – Grant Design and Setup\nAGO observed that the grant eligibility criteria and operational requirements for \nthe administration of the grant schemes were properly laid down in legislation or \nimplementation documents.  Proper contracts and agreements were entered into with \nexternal parties appointed to administer the schemes’ key processes.  Approval was also \nobtained from MOF for the funding of the schemes\n\nContext 14:\nYear: 2022_23\nLocation in document: PART III : THEMATIC AUDIT – COVID-19 RELATED GRANTS, SUMMARY\nPage number: 51\nContent: For RCG and RSS, the revenue eligibility assessment for automatic grant \nallotment was not fully in accordance with requirements stated in the legislation/\nimplementation document.  AGO also noted instances where manual grant assessments \nwere not adequately substantiated, or where there were wrong eligibility assessments \nand incorrect grant amounts computed\n\nQuery: What are the findings pertaining to grant?"
token_count = count_tokens(prompt, model = "gpt-4o")
print(f"Number of tokens: {token_count}")
# Out:
# Number of tokens: 1591

# %%
# Token indices sequence length is longer than the specified maximum sequence length for this model (2920 > 2048)
# can only use top_n ~ 15

# I ran with google colab
llm_lingua = PromptCompressor("microsoft/phi-2")
compressed_prompt = llm_lingua.compress_prompt(prompt, instruction="", question="", target_token=800)

# %%
compressed_prompt = '''Role:
 a specialist who uses the context provided to answer the query.


Your response should cite sources' year and page number
If, make ministries or government agencies the headings


The context is from reports from the AuditorGeneral's Office) of Singapore.
O is independent organ of state and the national auditor. They play in enhancing public accountability in the management public funds and resources through their audits
They audit
    government ministries and departments     state     boards    government funds    other public authorities and bodies administering funds (upon their request for audit),g. government-owned companies
They report their audit observations to the President, Parliament public through the ReportGeneral management of the organisationsited through management letters
Their observations include system weaknesses, with control procedures or, and of excess,ance, or grossefficiency to waste in the funds
TEXT
Context 0:
Year: 2019_20
Location in: PART III : THEICIT,ARY
Page:
: Stage 2: Grant Evaluation andval
– whether there were processes and to that
grant applications were approved; and
 whether agreements were properly into

:_ PARTIT –19 RELATED GRTS: Stage–	
Whether ensure
that grant
–	
Whether proper terms conditions wereulated for
compliance

Context: in: PART III: THEICIT,ARYPage:
: The audit examined whether there was a proper framework for grant
management and whether due followed for the above stages the two
encies.  For grants were jointly by A*STAR/F and one more
other audit onFs role and responsibilities
 management
::: Application, and grants
– whether the processes to invite, receive and approve
als and contract with recipients were properly
b

Context in THEICIT,Page:
: Stage: Grant and
 whether and to that
 were managed with relevant conditions,and that the were achieved
Context:: grant due process.   audit
 not to certify the grant had in all material, used or
 the the grant.  For
 were byG andG jointly with their programme partners ()
 as Tradeations and Chambers), the audit onGs
ands management
Context: in THEICIT –19TS,Page:
: Stage Grant and–	Whether and to ensure were managed with terms theContext:IT,: Stage Grant and– whether grantwere and reviewed for relevance
 8:
 in:VIEW,Page:
:

Grant and
AGO that MOH and had place for approving grant
 and of.  By,
 by both had and clear service
 were the correct authority
Context THEIC,:: Grant
 and that were and accordance the objective:IT –19,
Page:
: Grant and	 and ensurethat grant were andContext in THEIC,::, notedFor there
 better of PPs which on  Ps were different
of  O found their
 their checks applications::,
Page:
: Audit

A the findings to contract and financialThe and irregularities need the agencies to the
Context: in:: Grant and
O grant and forthe grant were properly in
plementation  per
 parties schemes�   was from the schemes: III : THEMATIC AUDIT – COVID-19 RELATED GRANTS, SUMMARY
Page number: 51
Content: For RCG and RSS, the revenue eligibility assessment for automatic grant 
allotment was not fully in accordance with requirements stated in the legislation/
implementation document.  AGO also noted instances where manual grant assessments 
were not adequately substantiated, or where there were wrong eligibility assessments 
and incorrect grant amounts computed

Query: What are the findings pertaining to grant?'''

# %%
response = gpt4o_untraced(compressed_prompt, llm)
# Out:
# ### Ministry of Health (MOH) and Economic Development Board (EDB):
# According to the Auditor-General's Office (AGO), MOH and EDB had an appropriate framework in place for the approving and disbursing of grants. For example, systems and clear procedures were established to ensure that grants were managed in accordance with their objectives (AGO, 2019-20, PART III, p. 8, VIEW).
#
# ### Key Findings on Grant Evaluation and Management:
# 1. **Approval Processes**: The audit examined whether there was a closed-loop framework for grant management, namely the processes for inviting, receiving, and approving applications, as well as the contract management with recipients. Deficiencies in these processes were noted, leading to concerns about whether due processes were followed (AGO, 2019-20, PART III, p. 8, THEIC).
#
# ...

# %%
# LongLLMLingua
# does not compress any contexts here (maybe too short)

prompt_list = ['''Role:
You are a specialist who uses the context provided to answer the query.

Instruction:
Your response should cite sources' year and page number.
If possible, make ministries or government agencies the headings.

Background:
The context is taken from audit reports from the Auditor-General's Office (AGO) of Singapore. 
AGO is an independent organ of state and the national auditor. They play an important role in enhancing public accountability in the management and use of public funds and resources through their audits.

They audit
    government ministries and departments
    organs of state
    statutory boards
    government funds
    other public authorities and bodies administering public funds (upon their request for audit), e.g. government-owned companies.

They report their audit observations to the President, Parliament and the public through the Annual Report of the Auditor-General management of the organisations audited through management letters.
Their observations include system weaknesses, non-compliance with control procedures or legislation, and instances of excess, extravagance, or gross inefficiency leading to waste in the use of public funds and resources.
''','AGO found weaknesses in IT controls in its audits of the Central Provident Fund \nBoard (CPFB), the Singapore Corporation of Rehabilitative Enterprises (SCORE), \nthe National Parks Board (NParks) and the Ministry of Social and Family \nDevelopment (MSF)', 'AGO found weaknesses in IT controls in its audits of several public sector entities \nsuch as the Ministry of Manpower (MOM), Singapore Customs (Customs) and the \nMinistry of Defence (MINDEF)', 'This report highlights the more significant \nobservations from AGO’s audits carried out for the financial year 2020/2021', 'AGO found weaknesses in IT controls in its audits of the Accounting and Corporate \nRegulatory Authority (ACRA), MOE and the Ministry of Defence (MINDEF)', 'AGO found weaknesses which may compromise the \nconfidentiality, integrity and availability of the system and data residing in the system', 'This report highlights the more significant \nobservations from AGO’s audits carried out for the financial year 2019/20', 'In this year’s audit, AGO found a number of instances where public \nsector entities, in response to lapses highlighted by AGO, explained that they had \ntaken actions in the past based on certain justifications but they were not able to \nprovide supporting documentation', '4\nOverview\nSummary of Audit Observations\nAGO’s audit observations for financial year 2018/19 are mainly in the areas of \nInformation Technology (IT) controls, contract management, procurement and \npayment, grant management and financial controls', '4\nOverview\nSummary of Audit Observations\nAGO’s audit observations for the financial year 2019/20 are mainly in the areas \nof Information Technology (IT) controls, procurement and contract management, \noperations management, and management of business grants', 'Summary of Audit Observations\nIn this year’s audits, AGO uncovered a number of instances of inadequate financial \ncontrols over Government operations including those outsourced to external \noperators', '1\nOVERVIEW\nI am pleased to present my Report on the audits carried out by the Auditor-General’s \nOffice (AGO) for the financial year 2020/21', 'It is of concern that despite the reporting of lapses in computer access controls found \nin various entities in previous Reports of the Auditor-General, AGO found similar \nlapses in other entities audited this year', 'The in-depth examination enables AGO\nto report on good practices in financial governance and controls that it may come\nacross in the course of the audit, in addition to lapses', 'The in-depth examination enables AGO \nto report on good practices in financial governance and controls that it may come \nacross in the course of the audit, in addition to lapses', 'The in-depth examination enables\nAGO to report on good practices in financial governance and controls that it\nmay come across in the course of the audit, in addition to lapses', 'The in-depth examination enables \nAGO to report on good practices in financial governance and controls that it \nmay come across in the course of the audit, in addition to lapses', '1\nOVERVIEW\nI am pleased to present my Report on the audits carried out by the Auditor-General’s \nOffice (AGO) for the financial year 2018/19', 'AGO’s findings can be found in the Report of the \nAuditor-General for the Financial Year 2021/22 published in July 2022', 'AGO’s findings can be found in the Report \nof the Auditor-General for the Financial Year 2021/22 published in July 2022', '1\nOVERVIEW\nI am pleased to present my Report on the audits carried out by the Auditor-General’s \nOffice (AGO) for the financial year 2019/20']

question = "Query: extract finding on weakness in access controls from FY2018/19 to FY2020/21 AGO's report. Tabulate the output with row heading as Year of Report and details of findings."

compressed_prompt_longllmlingua = llm_lingua.compress_prompt(
    prompt_list,
    question = question,
    rate=0.55,
    # Set the special parameter for LongLLMLingua
    condition_in_question="after_condition",
    reorder_context="sort",
    dynamic_context_compression_ratio=0.3, # or 0.4
    condition_compare=True,
    context_budget="+100",
    rank_method="longllmlingua",
)
print(compressed_prompt_longllmlingua["compressed_prompt"])

# %%
# Nothing happened

compressed_prompt_longllmlingua = '''
Role:
You are a specialist who uses the context provided to answer the query.

Instruction:
Your response should cite sources' year and page number.
If possible, make ministries or government agencies the headings.

Background:
The context is taken from audit reports from the Auditor-General's Office (AGO) of Singapore. 
AGO is an independent organ of state and the national auditor. They play an important role in enhancing public accountability in the management and use of public funds and resources through their audits.

They audit
    government ministries and departments
    organs of state
    statutory boards
    government funds
    other public authorities and bodies administering public funds (upon their request for audit), e.g. government-owned companies.

They report their audit observations to the President, Parliament and the public through the Annual Report of the Auditor-General management of the organisations audited through management letters.
Their observations include system weaknesses, non-compliance with control procedures or legislation, and instances of excess, extravagance, or gross inefficiency leading to waste in the use of public funds and resources.


It is of concern that despite the reporting of lapses in computer access controls found 
in various entities in previous Reports of the Auditor-General, AGO found similar 
lapses in other entities audited this year

AGO found weaknesses in IT controls in its audits of several public sector entities 
such as the Ministry of Manpower (MOM), Singapore Customs (Customs) and the 
Ministry of Defence (MINDEF)

AGO found weaknesses in IT controls in its audits the Accounting and Corporate 
Regulatory Authority (ACRA), MOE and the Ministry of Defence (MINDEF)

AGO found weaknesses in IT controls in its audits of the Central Provident Fund 
Board (FB), the Singapore Corporation of Rehabilitative Enterprises (SCORE), 
the National Parks Board (NParks) and the Ministry of Social and Family 
Development (MSF)

AGO found weaknesses which may compromise confidentiality, integrity and availability system and data residing in the system

The examination enables AGO report in financial governance and controls it may come across in the course of the in addition lapses


 ObservAGO�s for year 2018/ areas of  Technology (IT), contract management, 
, grant management controls4
Summary Audit ObservAG’ audit observations for year 2019/ in areas 
 Information Technology (), procurement 
operations management, and management of business grants

The in-depth examination enables AGO 
to report on good practices in financial governance and controls that it may come 
across in the course of the audit, in addition to lapses

The in-depth examination enables
AGO to report on good practices in financial governance and controls that it
may come across in the course of the audit, in addition to lapses

Query: extract finding on weakness in access controls from FY2018/19 to FY2020/21 AGO's report. Tabulate the output with row heading as Year of Report and details of findings.'''

# %%
llm_lingua2 = PromptCompressor(
    model_name="microsoft/llmlingua-2-xlm-roberta-large-meetingbank",
    use_llmlingua2=True, # Whether to use llmlingua-2
)
compressed_prompt_llm_lingua2 = llm_lingua2.compress_prompt(prompt, rate=0.8, force_tokens = ['\n', '?'])
print(compressed_prompt_llm_lingua2["compressed_prompt"])

# %%
compressed_prompt_llm_lingua2 = '''
Role:
 You specialist uses context to answer query.

 Instruction:
 response cite sources' year page number.
 possible make ministries or government agencies headings.

 Background:
 context taken from audit reports Auditor-General's Office (AGO) of Singapore
 AGO independent organ state national auditor important role enhancing public accountability in management use of public funds resources through audits

 audit
 government ministries departments
 organs of state
 statutory boards
 government funds
 other public authorities bodies administering public funds (upon request audit), government-owned companies.

 report audit observations to President Parliament public through Annual Report of Auditor-General management organisations audited management letters
 observations include system weaknesses non-compliance with control procedures legislation instances of excess extravagance gross inefficiency leading to waste in use public funds resources.

 CONTEXT
 Context 0:
 Year: 2021_22
 Location in document: PART II : AUDIT OF STATUTORY BOARDS, MINISTRY OF EDUCATION, SkillsFuture Singapore Agency Lapses in Management of Grants
 Page number: 39
 Content: 39
 II: Audit of Statutory Boards
 Key Audit Observations
 Amount
 of Grants
 Disbursed with
 Lapses Noted3
 ($
 Estimated
 Overpayment


 Inadequate Monitoring Lapses on
 Checks for Grant Eligibility
 2,587,800

 Inadequate Checks by Service Provider on
 Grant Claims of Training Providers
 953,600

 Grants Disbursed for Individuals
 Companies Disallowed Funding
 269,100

 Grants Disbursed for Individuals with

 Overlapping Attendance Records for
 Synchronous Courses
 3,290,800
 13,300
Inadequate Checks/Supporting Documents
 for Absentee Payroll Funding
 615,100
 393,700
 Total
 7,716,400
 4,217,500
 14

 Context 1:
 Year: 2019_20
 Location document: PART III : THEMATIC AUDIT, SUMMARY
 Page number: 56
 Content audit AGO noted need to strengthen oversight
 of PPs administer grant programmes behalf WSG and ESG
 AGO understands need provide flexibility to PPs in applying grant
 guidelines important ensure baseline requirements met adequate
 measures place reduce inconsistency across PPs administering
 grants. assessment of grant applicants’ eligibility verification of
 supporting documents could be improved

 Context 2:
 Year: 2019_20
 Location document PART III : THEMATIC AUDIT, SUMMARY
 Page number: 61
 Content Management of grant records improved ensure key
 grant information on applications disbursements correctly
 maintained


 Context 3:
 Year: 2021_22
 Location document OVERVIEW, SUMMARY
 Page number: 4
 Content: Lapses noted included grants disbursed for individuals companies
 not meet grant eligibility criteria or disallowed funding grants
 disbursed for individuals attended two or more sessions for different courses
 same time (iii inadequate checks for absentee payroll funding

 Context 4:
 Year: 2014_15
 Location document: PART I B: AUDIT OF GOVERNMENT MINISTRIES, ORGANS OF STATE AND GOVERNMENT FUNDS, PRIME MINISTER’S OFFICE, National Research Fund, Lapses in Administration of Grants
 Page number: 18
 Content For proper accountability avoid wastage of public funds disbursed
 for research projects important reviews carried out timely
prompt action on projects not making
 satisfactory progress

 Context 5:
 Year: 2022_23
 Location document: PART III : THEMATIC AUDIT – COVID-19 RELATED GRANTS, MINISTRY OF FINANCE, Inland Revenue Authority of Singapore, Jobs Support Scheme, SUMMARY
 Page number: 63
 Content: Improve evaluation of grant applications ensure proper
 assessment of grant eligibility computation of grant quantum

 Context 6:
 Year: 2009_10
 Location document: PART I B : AUDIT OF GOVERNMENT MINISTRIES ORGANS OF STATE, Judicature
 Page number: 17
 Content Under Arts Housing Scheme (AHS), National Arts Council (NAC)
 lease suitable buildings from Government at market rate renovate
 rent to artists arts groups at subsidised rates. main objective
 AHS to facilitate development growth of artists arts groups
 play greater role in cultural development of Singapore

 Context 7:
 Year: 2019_20
 Location document: PART III : THEMATIC AUDIT, MINISTRY OF MANPOWER, Workforce Singapore Agency, Possible Circumvention of Eligibility Criterion Possible Fraudulent Grant Claims
 Page number: 65
 Content not aggregate grant applications for seeking approval for
 grant award. For one company PP approved total 10 grant applications
 (cumulative amount of $945,000) for company within six-month period. Each
 grant application below $100,000 threshold beyond higher level
 approving authority audit required. not aggregating similar grant
 applications from same company grant awards of significant sums might not be
 subject to stringent controls for higher value grants

 Context 8:
 Year: 2018_19
 Location document: OVERVIEW, SUMMARY
 Page number: 4
 Content: For management of social grant programmes AGO noted
 established processes for grant application, evaluation approval in two
ministries AGO conducted thematic audit on. AGO observed
 need to strengthen controls in areas timeliness in obtaining
 approval of funding, verification of grant disbursements monitoring and
 review of documents due from grant recipients

 Context 9:
 Year: 2019_20
 Location in document: PART III : THEMATIC AUDIT, SUMMARY
 Page number: 58
 Content: AGO understands ESG adopted customer-centric approach aim to
 reduce administrative burden of companies TACs in applying for grants
 address specific requirements of different industries. In AGO’s view
 needs to adequate measures to reduce inconsistencies in grant administration
 ensure grants administered in fair and equitable manner

 Context 10:
 Year: 2017_18
 Location in document: OVERVIEW, SUMMARY
 Page number: 4
 Content: For management of R&D grants, AGO noted established
 processes for grant application, evaluation award in two public sector entities
 AGO conducted thematic audit on. AGO observed
 need to strengthen controls in areas monitoring and review of

 progress/final reports audit reports recovery of unutilised funds

 Context 11:
 Year: 2017_18
 Location in document: PART III: THEMATIC AUDIT, SUMMARY
 Page number: 45
 Content: Disbursement of grants
 – processes in place to ensure grants
 disbursed in accurate timely manner
 c

 Context 12:
 Year: 2017_18
 Location in document: PART III: THEMATIC AUDIT, SUMMARY
 Page number: 45
 Content: audit examined proper framework for grant
 management due process followed for above stages by two
 agencies. For grants jointly managed by A*STAR/NRF and one or more
agencies audit focus on A*STAR/NRF’s role responsibilities in
 grant management

 Context 13:
 Year: 2019_20
 Location document: PART III : THEMATIC AUDIT, SUMMARY
 Page number: 60
 Content processes in place to approve new grant programmes
 renew or revise grant programmes changes
 in circumstances


 Context 14:
 Year: 2017_18
 Location document: OVERVIEW, SUMMARY
 Page number: 8
 Content:
 Gaps in Management of R&D Grants
 R&D important part of Singapore’s economic strategy Total R&D expenditure
 increased significantly over years Under Research and Innovation Enterprise
 2015 plan boost research innovation enterprise A*STAR and NRF
 two key public sector entities responsible for managing R&D grant programmes

 Context 15:
 Year: 2014_15
 Location document: OVERVIEW, SUMMARY
 Page number: 3
 Content Audit Observations
 audits AGO uncovered instances indicated laxity in
 administration of grants common weaknesses include failure by
 public sector entities to ensure correct amount of grants disbursed
 conditions for grants adhered to For accountability important
 controls proper mechanisms in place to ensure grants used for
 intended purposes

 Context 16:
 Year: 2014_15
 Location document: PART I B: AUDIT OF GOVERNMENT MINISTRIES, ORGANS OF STATE AND GOVERNMENT FUNDS, PRIME MINISTER’S OFFICE, National Research Fund, Lapses in Administration of Grants
 Page number: 17
 Content AGO carried test checks on projects awarded from 2007 to 2013 under
 three grant schemes by NRF Proof-of-Concept (POC)
 Grant Scheme, Competitive Research Programme (CRP) Funding Scheme
 NRF Fellowship SchemePOC Grant Scheme funds research on inventions
 ideas licensed or marketed; CRP Funding Scheme funds
 high-impact research relevance to Singapore; NRF Fellowship Scheme
 supports outstanding early-stage career researchers independent
 research in Singapore. amount disbursed from National Research Fund for
 three schemes as at 31 December 2013 was $301.20 million

 Context 17:
 Year: 2014_15
 Location document: OVERVIEW, SUMMARY
 Page number: 4
 Content: 4
 Overview
 Administration of Grants
 Significant amounts grants disbursed every year for various Government
 programmes projects. public funds involved important adequate
 controls monitoring mechanisms in place to track use of grants
 monitor grants disbursed achieved intended purposes

 Context 18:
 Year: 2019_20
 Location document: PART III : THEMATIC AUDIT, SUMMARY
 Page number: 54
 Content: audit examined proper framework for grant
 management due process followed for above stages. audit
 not seek certify grant recipients used
 managed grants in accordance with grant terms and conditions. For grants
 managed by WSG and ESG jointly with programme partners (PPs)
 Trade Associations and Chambers (TACs), audit focus on WSG’s
 ESG’s roles responsibilities in grant management

 Context 19:
 Year: 2017_18
 Location in document: Introduction
 Page number: Before first page
 Content: ............................. 49
 Lapses in Monitoring and Review of Progress and Final Reports ..... 50
 PRIME MINISTER’S OFFICE
 National Research Foundation
 Lack of Framework Leading to Inconsistencies in
 Grant Management 52
 Laxity in Verification of Fund Requests 53
 No Monitoring of Audit Reports ........................................................ 54
Laxity Monitoring Progress Final Reports .............................. 55
 No Procedures Recover Unutilised Grants
 from Grant Recipients 56
 P
 ART IV : AUDIT GOVERNMENT-OWNED COMPANIES


 OTHER ACCOUNTS

 Query: findings pertaining grant?
'''

response = gpt4o_untraced(compressed_prompt_llm_lingua2, llm)
# Out:
# To provide an overview of the findings related to grants based on the audit reports from the Auditor-General's Office (AGO) of Singapore, here are some key observations across different years and entities:
#
# ### SkillsFuture Singapore Agency (Ministry of Education)
# **Year:** 2021-22
# **Audit Findings:**
# - **Inadequate Monitoring and Lapses on Checks for Grant Eligibility:** Estimated overpayment of $2,587,800.
# - **Inadequate Checks by Service Provider on Grant Claims:** Estimated overpayment of $953,600.
# - **Grants Disbursed for Ineligible Individuals and Companies:** Total discrepancy of $269,100.
# - **Grants Disbursed for Individuals with Overlapping Attendance Records:** Total discrepancy of $3,290,800.
# - **Inadequate Checks/Supporting Documents for Absentee Payroll Funding:** Overpayment reported as $393,700 out of $615,100 in total [2021_22, pp. 39, 4].
#
# ### Thematic Audit Observations
# **Year:** 2019-20
# **Audit Findings:**
# ...

# %%
compressed_prompt_llm_lingua2 = llm_lingua2.compress_prompt(prompt, rate=0.6, force_tokens = ['\n', '?'])
print(compressed_prompt_llm_lingua2["compressed_prompt"])

# %%
compressed_prompt_llm_lingua2 = '''Role:
 You are a specialist who uses the context provided to answer the query.

 Instruction:
 Your response should cite sources' year and page number.
 If possible, make ministries or government agencies the headings.

 Background
 context from audit reports Auditor-General's Office (AGO Singapore
 AGO independent state national auditor public accountability management public funds resources audits

 audit
 government ministries departments
 organs state
 statutory boards
 government funds
 public authorities bodies administering funds government-owned companies

 report audit observations President Parliament public Annual Report Auditor-General
 observations include system weaknesses non-compliance control procedures legislation excess extravagance inefficiency waste use public funds resources

 CONTEXT

 Year 2021_22
 Location document II AUDIT OF STATUTORY BOARDS MINISTRY OF EDUCATION SkillsFuture Singapore Agency Management Grants
 Page number 39
 Content
 II Audit Statutory Boards
 Key Audit Observations
 Amount
 Grants
 Disbursed
 Lapses

 Estimated
 Overpayment


 Inadequate Monitoring Lapses
 Checks Grant Eligibility
 2,587,800

 Inadequate Checks Service Provider
 Grant Claims Training Providers
 953,600

 Grants Disbursed Individuals
 Companies Disallowed Funding
 269,100

 Grants Disbursed Individuals

 Overlapping Attendance Records
 Synchronous Courses
 3,290,800

Inadequate Checks/Supporting Documents
 Absentee Payroll Funding
 615,100
 393,700
 Total
 7,716,400
 4,217,500
 14

 Context 1:
 Year 2019_20
 Location III THEMATIC AUDIT SUMMARY
 Page 56
 audit AGO noted need strengthen oversight
 PPs grant programmes WSG ESG
 AGO understands need flexibility PPs applying grant
 guidelines important ensure baseline requirements met
 measures reduce inconsistency PPs administering
 grants assessment grant applicants’ eligibility verification
 supporting documents improved

 Context 2:
 Year 2019_20
 Location III : THEMATIC AUDIT SUMMARY
 Page 61
 Management grant records improved ensure key
 grant information applications disbursements
 maintained


 Context 3:
 Year 2021_22
 Location SUMMARY
 Page 4
 Lapses noted grants disbursed individuals companies
 meet eligibility criteria disallowed funding grants
 individuals attended two more sessions different courses
 inadequate checks absentee payroll funding

 Context 4:
 Year 2014_15
 Location I B AUDIT GOVERNMENT MINISTRIES ORGANS OF STATE GOVERNMENT FUNDS PRIME MINISTER’S OFFICE National Research Fund Administration Grants
 Page 18
 accountability avoid wastage public funds
 research projects important reviews timely
prompt action on projects not
 satisfactory progress

 Context 5
 Year 2022_23
 Location document PART III : THEMATIC AUDIT – COVID-19 RELATED GRANTS MINISTRY OF FINANCE Inland Revenue Authority Singapore Jobs Support Scheme
 Page 63
 Improve evaluation grant applications
 assessment grant eligibility computation grant quantum

 Context 6
 Year 2009_10
 I B : AUDIT OF GOVERNMENT MINISTRIES STATE Judicature
 Page 17
 Arts Housing Scheme National Arts Council)
 lease buildings Government market rate renovate
 rent artists arts groups subsidised rates objective
 facilitate development growth artists arts groups
 role cultural development Singapore

 Context 7
 Year 2019_20
 III : THEMATIC AUDIT MINISTRY OF MANPOWER Workforce Singapore Agency Possible Circumvention Eligibility Criterion Fraudulent Grant Claims
 Page 65
 aggregate grant applications approval
 grant award one company PP approved 10 grant applications
 (cumulative amount $945,000) six-month period Each
 grant application below $100,000 higher
 approving authority audit required not aggregating similar grant
 applications company grant awards significant sums not
 subject stringent controls higher value grants

 Context 8:
 Year 2018_19
 Location document OVERVIEW SUMMARY
 Page 4
 management social grant programmes AGO noted
 established processes for grant application evaluation approval two
ministries AGO conducted thematic audit observed
 need to strengthen controls timeliness obtaining
 approval funding verification grant disbursements monitoring
 review of documents from grant recipients

 Context 9
 Year 2019_20
 Location document PART III : THEMATIC AUDIT SUMMARY
 Page 58
 AGO understands ESG adopted customer-centric approach
 reduce administrative burden companies TACs applying grants
 address specific requirements different industries
 measures reduce inconsistencies in grant administration
 ensure grants fair equitable

 Context 10:
 Year 2017_18
 Location document OVERVIEW SUMMARY
 Page 4
 management R&D grants AGO noted established
 processes for grant application evaluation award two public sector entities
 conducted audit observed
 need to strengthen controls monitoring review

 progress/final reports audit reports recovery of unutilised funds

 Context 11:
 Year 2017_18
 Location document III: THEMATIC AUDIT SUMMARY
 Page 45
 Content Disbursement of grants
 processes ensure grants
 accurate timely


 Context 12:
 Year: 2017_18
 Location document III: THEMATIC AUDIT SUMMARY
 Page 45
 audit examined proper framework for grant
 management due process followed stages by two
 agencies grants jointly managed by A*STAR/NRF one more
audit focus on A*STAR/NRF’s role responsibilities
 grant management

 Context 13
 Year 2019_20
 Location III : THEMATIC AUDIT SUMMARY
 Page 60
 processes to approve new grant programmes
 renew revise programmes changes
 circumstances


 Context 14
 Year 2017_18
 Location OVERVIEW SUMMARY
 Page 8

 Gaps in Management of R&D Grants
 R&D important Singapore’s economic strategy R&D expenditure
 increased Research and Innovation Enterprise
 2015 plan A*STAR NRF
 key public sector entities managing R&D grant programmes

 Context 15
 Year 2014_15
 Location SUMMARY
 Page 3
 Audit Observations
 AGO uncovered instances laxity in
 administration grants weaknesses include failure
 public sector entities ensure correct grants disbursed
 conditions adhered
 controls mechanisms ensure grants used
 intended purposes

 Context 16
 Year 2014_15
 Location I B: AUDIT OF GOVERNMENT MINISTRIES OF STATE FUNDS PRIME MINISTER’S OFFICE National Research Fund Lapses in Administration of Grants
 Page 17
 AGO test checks on projects awarded 2007 to 2013 under
 three grant schemes NRF Proof-of-Concept (POC)
 Grant Scheme Competitive Research Programme (CRP) Funding Scheme
 NRF Fellowship SchemePOC Grant Scheme funds research inventions
 ideas licensed marketed CRP Funding Scheme funds
 high-impact research Singapore NRF Fellowship Scheme
 supports early-stage researchers independent
 research Singapore disbursed from National Research Fund for
 three schemes 31 December 2013 $301.20 million

 Context 17
 Year 2014_15
 Location document OVERVIEW SUMMARY
 Page 4
 Content

 Administration Grants
 grants disbursed for Government
 programmes projects public funds involved important
 controls monitoring mechanisms track use grants
 monitor grants intended purposes

 Context 18
 Year 2019_20
 Location document III : THEMATIC AUDIT SUMMARY
 Page 54
 audit examined proper framework for grant
 management due process audit
 certify grant recipients used
 managed grants accordance grant terms conditions grants
 managed by WSG ESG partners
 Trade Associations Chambers audit focus on WSG’s
 ESG’s roles responsibilities grant management

 Context 19
 Year 2017_18
 Location document Introduction
 Page number
 Content 49
 Lapses in Monitoring Review of Progress Final Reports
 PRIME MINISTER’S OFFICE
 National Research Foundation
 Lack of Framework Inconsistencies in
 Grant Management 52
 Laxity in Verification of Fund Requests 53
 No Monitoring of Audit Reports 54
Laxity Monitoring Progress Final Reports 55
 No Procedures Recover Unutilised Grants
 Recipients 56

 ART IV AUDIT-OWNED COMPANIES


 ACCOUNTS

 Query: What are the findings pertaining to grant?'''

response = gpt4o_untraced(compressed_prompt_llm_lingua2, llm)
# Out:
# ### Ministry of Education: SkillsFuture Singapore Agency
#
# **Key Audit Observations (Year 2021-22, Page 39)**:
# 1. **Inadequate Monitoring and Checks**: Lapses were observed in the monitoring and verification of grant eligibility, leading to an estimated overpayment.
#     - Overpayment of $2,587,800 due to inadequate checks on grant eligibility.
#     - Lack of checks on service provider claims, leading to an overpayment of $953,600.
#     - Disbursements to individuals and companies that were disallowed, resulting in an overpayment of $269,100.
#     - Individuals recorded overlapping attendance for synchronous courses, contributing to an overpayment of $3,290,800.
#     - Inadequate checks and supporting documents for absentee payroll funding led to overpayments of $615,100 and $393,700.
#     - **Total Estimated Overpayment**: $7,716,400.
#
# *(Source: Year 2021-22, Page 39)*
#
# ### Workforce Singapore and ESG
#
# **Strengthening Oversight (Year 2019-20, Page 56)**:
# ...

# %%
compressed_prompt_llm_lingua2 = '''Role:
 You are a specialist who uses the context provided to answer the query.

 Instruction:
 Your response should cite sources' year and page number.
 If possible, make ministries or government agencies the headings.

 Background
 context from audit reports Auditor-General's Office (AGO) Singapore
 AGO independent organ state national auditor public accountability management use public funds resources audits

 audit
 government ministries departments
 organs state
 statutory boards
 government funds
 public authorities bodies administering public funds government-owned companies

 report audit observations President Parliament public Annual Report Auditor-General
 observations include system weaknesses non-compliance control procedures legislation excess extravagance gross inefficiency waste use public funds resources

 CONTEXT

 Year 2016_17
 Location document OVERVIEW SUMMARY
 Page number 5
 found weaknesses in IT controls audits Central Provident Fund
 Board Singapore Corporation of Rehabilitative Enterprises
 National Parks Board Ministry of Social and Family
 Development weaknesses include inadequate review
 IT systems wrongful use privileged accounts officers vendors
 lack of review user access rights

 Context 1:
 Year 2018_19
 Location document OVERVIEW SUMMARY
 Page number 5
 AGO found weaknesses IT controls audits public sector entities
 Ministry of Manpower Singapore Customs
 Ministry of Defence included inadequate logging review
activities privileged users operating system database
 administrators lapses management user access rights AGO noted
 privileged users staff IT vendors

 Context 2:
 Year 2020_21
 Location CONTENTS OVERVIEW SUMMARY
 Page 9
 Concluding
 AGO’s audits enhance public accountability strengthen financial
 governance public sector entities report highlights
 observations audits financial year 2020/2021

 Context 3:
 Year 2017_18
 SUMMARY
 Page 6
 found weaknesses IT controls audits Accounting Corporate
 Regulatory Authority MOE Ministry of Defence
 no monitoring privileged users’ activities lapses management
 user accounts access rights

 Context 4:
 Year 2022_23
 I AUDIT GOVERNMENT MINISTRIES STATE FUNDS PRIME MINISTER’S OFFICE Public Service Division Weak Controls Most Privileged Operating System Database Accounts
 Page 21
 AGO conducted IT general controls audit HRP
 April 2022 to January 2023 found weaknesses
 confidentiality integrity availability system data residing

 Context 5
 Year 2019_20
 OVERVIEW SUMMARY
 Page 9
 Concluding
 AGO’s audits enhance public accountability strengthen financial
 governance public sector entities report highlights
 observations audits financial year 2019/20

 Context 6
 Year 2014_15
 OVERVIEW SUMMARY
 Page 6
Importance of Proper Documentation
 concerned over lack of documentation
 on decisions actions financial implications in
 areas audited this year’s audit AGO found instances where public
 sector entities lapses
 taken actions past not
 provide supporting documentation AGO informed verbal
 approvals obtained discussions not recorded

 Context 7
 Year 2018_19
 document OVERVIEW SUMMARY
 Page number 4


 Summary of Audit Observations
 audit observations financial year 2018/19
 Information Technology (IT) controls contract management procurement
 payment grant management financial controls observations
 conveyed to public sector entities through AGO Management
 Letters significant audit observations to 7 out
 16 Government ministries 2 of 4 Government funds 4 out of 9 statutory
 boards audited highlighted summarised into
 key areas

 Context 8
 Year 2019_20
 document OVERVIEW SUMMARY
 Page number 4


 Summary of Audit Observations
 audit observations financial year 2019/20
 Information Technology (IT) controls procurement contract management
 operations management management business grants
 conveyed to public sector entities through AGO Management
 Letters significant audit observations relating to 3 out
 16 Government ministries 8 out of 13 statutory boards audited highlighted
 key areas

 Context 9
 Year: 2015_16
 document OVERVIEW SUMMARY
 Page number 4
Summary Audit Observations
 this year’s audits AGO uncovered inadequate financial
 controls over Government operations including outsourced to external
 operators cases inadequate controls over collection fees
 loss revenue Government instances controls
 inadequate for ensuring correct payments for services rendered

 Context 10
 Year 2020_21
 Location document CONTENTS OVERVIEW SUMMARY
 Page number 1


 Report on audits Auditor-General’s
 Office (AGO) financial year 2020/21

 Context 11
 Year 2012_13
 document OVERVIEW SUMMARY
 Page 5
 concern despite reporting lapses computer access controls
 previous Reports AGO found similar
 lapses in other entities audited this year Weak controls over access rights could
 compromise integrity confidentiality of data IT systems Public
 sector entities afford be lax operations
 highly computerised

 Context 12
 Year 2020_21
 Location document CONTENTS III : THEMATIC AUDIT SUMMARY
 Page 73
 thematic audit in-depth examination selected area
 more than one public sector entity enables AGO
 report on good practices financial governance controls
 lapses

 Context 13
 Year 2017_18
 III: THEMATIC AUDIT SUMMARY
 Page 44
 thematic audit in examination selected area
 more than one public sector entity AGO
report good practices financial governance controls
 audit lapses

 Context 14:
 Year 2020_21
 Location document CONTENTS OVERVIEW SUMMARY
 Page 1

 Thematic audit in-depth examination selected area
 more than one public sector entity enables
 AGO report good practices financial governance controls
 audit lapses

 Context 15:
 Year 2017_18
 Location document SUMMARY
 Page 1
 Content
 Thematic audit in-depth examination selected area
 more than one public sector entity enables
 AGO report good practices financial governance controls
 lapses

 Context 16:
 Year 2018_19
 Location document OVERVIEW SUMMARY
 Page 1


 present Report audits Auditor-General’s
 Office (AGO) financial year 2018/19

 Context 17:
 Year 2022_23
 Location document III THEMATIC AUDIT COVID-19 RELATED GRANTS SUMMARY
 Page 46
 Content
 Thematic audit financial year 2021/22
 COVID-19 related procurement expenditure 3 agencies
 Ministry of Manpower Health Promotion Board
 Singapore Land Authority total expenditure
 AGO’s audit $1.51 billion period 1 January 2020 to
 31 March 2021 AGO’s findings Report
 Auditor-General Financial Year 2021/22 July 2022

 Context 18:
 Year 2022_23
 Location document OVERVIEW SUMMARY
 Page 8
 Content Part 1: financial year 2021/22 AGO audited COVID-19
procurement expenditure 3 agencies Ministry of










 Manpower Health Promotion Board Singapore Land Authority
 total expenditure audit $1.51 billion period
 1 January 2020 to 31 March 2021 findings Report
 Auditor-General Financial Year 2021/22 July 2022

 Context
 Year 2019_20
 Location document SUMMARY
 Page number 1
 Content

 present Report audits Auditor-General’s
 Office financial year 2019/20

 Query: extract finding on weakness in access controls from FY2018/19 to FY2020/21 AGO's report. Tabulate the output with row heading as Year of Report and details of findings.
'''
response = gpt4o_untraced(compressed_prompt_llm_lingua2, llm)

# compressed question results in llm not using tables. Need to seperately attach question.
# Out:
# The table below summarizes the findings on weaknesses in access controls from the AGO reports for FY2018/19 to FY2020/21:
#
# | **Year of Report** | **Details of Findings**                                                                                            |
# |--------------------|--------------------------------------------------------------------------------------------------------------------|
# | 2018/19            | AGO found weaknesses in IT controls in audits of public sector entities, including the Ministry of Manpower and Singapore Customs. These weaknesses included inadequate logging and review of activities of privileged users, as well as lapses in the management of user access rights (Overview Summary, p. 5). Additionally, significant audit observations were related to 7 out of 16 government ministries, 2 out of 4 government funds, and 4 out of 9 statutory boards (Overview Summary, p. 4). |
# ...

# %%
compressed_prompt_llm_lingua2 = llm_lingua2.compress_prompt(prompt, rate=0.6, force_tokens = ['\n', '?'])
print(compressed_prompt_llm_lingua2["compressed_prompt"])
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1832 > 512). Running this sequence through the model will result in indexing errors
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Role
#  specialist context answer query
#
#  Instruction
#  response cite sources' year page number
#  make ministries government agencies headings
#
#  Background
#  context from audit reports Auditor-General's Office (AGO) Singapore
#  AGO independent organ state national auditor role public accountability management use public funds resources audits
#
#  audit
#  government ministries departments
#  organs state
#  statutory boards
#  government funds
#  public authorities bodies administering public funds request government-owned companies
#
# ...
